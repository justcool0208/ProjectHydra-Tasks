# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import tensorflow

# %% [markdown]
# ## Data Preprocessing

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# row number , customer id and surname dont play any rule in churn modelling
X = df.drop(['RowNumber','CustomerId','Surname','Exited'],axis=1)
y = df['Exited']

# %%
print(X.shape)
print(y.shape)
print(X)
print(y)
# Out:
# (10000, 10)
# (10000,)
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
## encoding geo which is column 1

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

X['Gender'] = le.fit_transform(X['Gender'])

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       1   39       5       0.00              2
# 9996          516    France       1   35      10   57369.61              1
# 9997          709    France       0   36       7       0.00              1
# 9998          772   Germany       1   42       3   75075.31              2
# 9999          792    France       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
X = ct.fit_transform(X)

# %%
X
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0134888e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.1254258e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1393157e+05],
#        ...,
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 4.2085580e+04],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 9.2888520e+04],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 3.8190780e+04]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (8000, 12)

# %% [markdown]
# ## Building ANN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=12, activation='relu'))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True
)
model.fit(
    X_train,
    y_train,
    batch_size=32,
    epochs=100,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7384 - loss: 0.5792 - val_accuracy: 0.7987 - val_loss: 0.4812
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7944 - loss: 0.4889 - val_accuracy: 0.8056 - val_loss: 0.4532
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8079 - loss: 0.4430 - val_accuracy: 0.8069 - val_loss: 0.4419
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8168 - loss: 0.4321 - val_accuracy: 0.8081 - val_loss: 0.4362
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8147 - loss: 0.4290 - val_accuracy: 0.8106 - val_loss: 0.4309
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8226 - loss: 0.4125 - val_accuracy: 0.8150 - val_loss: 0.4256
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8202 - loss: 0.4192 - val_accuracy: 0.8188 - val_loss: 0.4207
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8322 - loss: 0.4046 - val_accuracy: 0.8200 - val_loss: 0.4146
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8343 - loss: 0.4014 - val_accuracy: 0.8231 - val_loss: 0.4076
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8341 - loss: 0.3989 - val_accuracy: 0.8325 - val_loss: 0.4020
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8399 - loss: 0.3856 - val_accuracy: 0.8375 - val_loss: 0.3949
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8379 - loss: 0.3768 - val_accuracy: 0.8375 - val_loss: 0.3904
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8444 - loss: 0.3744 - val_accuracy: 0.8425 - val_loss: 0.3862
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8526 - loss: 0.3573 - val_accuracy: 0.8462 - val_loss: 0.3835
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8388 - loss: 0.3663 - val_accuracy: 0.8425 - val_loss: 0.3794
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8509 - loss: 0.3517 - val_accuracy: 0.8500 - val_loss: 0.3763
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8495 - loss: 0.3567 - val_accuracy: 0.8506 - val_loss: 0.3744
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8593 - loss: 0.3437 - val_accuracy: 0.8494 - val_loss: 0.3715
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8553 - loss: 0.3476 - val_accuracy: 0.8512 - val_loss: 0.3687
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8556 - loss: 0.3460 - val_accuracy: 0.8525 - val_loss: 0.3672
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8546 - loss: 0.3440 - val_accuracy: 0.8519 - val_loss: 0.3659
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8598 - loss: 0.3397 - val_accuracy: 0.8512 - val_loss: 0.3651
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8499 - loss: 0.3463 - val_accuracy: 0.8556 - val_loss: 0.3634
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8662 - loss: 0.3307 - val_accuracy: 0.8550 - val_loss: 0.3611
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8638 - loss: 0.3361 - val_accuracy: 0.8544 - val_loss: 0.3631
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8583 - loss: 0.3401 - val_accuracy: 0.8569 - val_loss: 0.3611
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8651 - loss: 0.3295 - val_accuracy: 0.8569 - val_loss: 0.3604
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8652 - loss: 0.3293 - val_accuracy: 0.8594 - val_loss: 0.3604
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8562 - loss: 0.3526 - val_accuracy: 0.8581 - val_loss: 0.3613
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8643 - loss: 0.3345 - val_accuracy: 0.8525 - val_loss: 0.3614
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8579 - loss: 0.

#   0.8493750095367432,
#   0.8512499928474426,
#   0.8525000214576721,
#   0.8518750071525574,
#   0.8512499928474426,
#   0.8556249737739563,
#   0.8550000190734863,
#   0.8543750047683716,
#   0.8568750023841858,
#   0.8568750023841858,
#   0.859375,
#   0.8581249713897705,
#   0.8525000214576721,
#   0.8581249713897705,
#   0.8550000190734863,
#   0.8581249713897705,
#   0.8575000166893005,
#   0.8581249713897705,
#   0.859375,
#   0.8581249713897705,
#   0.8556249737739563],
#  'val_loss': [0.48117464780807495,
#   0.4531644582748413,
#   0.4418915808200836,
#   0.4361971318721771,
#   0.43093162775039673,
#   0.42555224895477295,
#   0.4206807315349579,
#   0.4146121144294739,
#   0.4075999855995178,
#   0.40200576186180115,
#   0.39489737153053284,
#   0.3904133141040802,
#   0.38621166348457336,
#   0.3834945559501648,
#   0.37944096326828003,
#   0.3762543499469757,
#   0.3744327425956726,
#   0.3715415298938751,
#   0.36874446272850037,
#   0.36724087595939636,
#   0.3659370541572571,
#   0.3650667071342468,
#   0.363437682390213,
#   0.3611399829387665,
#   0.36305832862854004,
#   0.3610585033893585,
#   0.3603881895542145,
#   0.3604160249233246,
#   0.36128053069114685,
#   0.36139899492263794,
#   0.358621746301651,
#   0.35941657423973083,
#   0.35827094316482544,
#   0.3593129813671112,
#   0.35832083225250244,
#   0.35906127095222473,
#   0.3593415915966034,
#   0.3574126362800598]}

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (32, 12)               │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (32, 8)                │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (32, 1)                │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 809 (3.16 KB)
#  Trainable params: 269 (1.05 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 540 (2.11 KB)

# %%
model.evaluate(X_test,y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8604 - loss: 0.3391
# [0.34327346086502075, 0.8615000247955322]

# %%
# Raw input
custom = [[600,'France','Male',40,3,60000,2,1,1,50000]]

df_custom = pd.DataFrame(custom, columns=[
    'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
    'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary'
])

df_custom['Gender'] = le.transform(df_custom['Gender'])

df_custom = ct.transform(df_custom)

df_custom = sc.transform(df_custom)

# %%
ans = model.predict(df_custom)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step

# %%
ans
# Out:
# array([[0.03650641]], dtype=float32)

# %%
print("YES" if ans >= 0.5 else "NO")
# Out:
# NO

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
y_true = y_test.values
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

print("Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[1522   73]
#  [ 204  201]]
# Accuracy: 0.8615
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      1595
#            1       0.73      0.50      0.59       405
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %% [markdown]
# Precision, recall, and F1-score are metrics used to evaluate classification models, especially when the data is imbalanced.
#
# Precision shows how often the model’s positive predictions are actually correct, while recall shows how many of the real positive cases the model is able to find. F1-score combines both precision and recall into a single value, giving a balanced measure of performance.
#
# These metrics are more reliable than accuracy alone because accuracy can look high even when a model performs poorly on important classes. Precision, recall, and F1-score give deeper insight into the types of mistakes the model makes.
#
# Other useful metrics include specificity, ROC-AUC, log loss, and MCC, which help evaluate different aspects of model performance.
