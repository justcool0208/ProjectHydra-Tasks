# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import tensorflow

# %% [markdown]
# ## Data Preprocessing

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# row number , customer id and surname dont play any rule in churn modelling
X = df.drop(['RowNumber','CustomerId','Surname','Exited'],axis=1)
y = df['Exited']

# %%
print(X.shape)
print(y.shape)
print(X)
print(y)
# Out:
# (10000, 10)
# (10000,)
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
## encoding geo which is column 1

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

X['Gender'] = le.fit_transform(X['Gender'])

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       1   39       5       0.00              2
# 9996          516    France       1   35      10   57369.61              1
# 9997          709    France       0   36       7       0.00              1
# 9998          772   Germany       1   42       3   75075.31              2
# 9999          792    France       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
X = ct.fit_transform(X)

# %%
X
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         1.0000000e+00, 1.0134888e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.1254258e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.1393157e+05],
#        ...,
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 4.2085580e+04],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 9.2888520e+04],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 3.8190780e+04]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Building ANN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True
)
model.fit(
    X_train,
    y_train,
    batch_size=32,
    epochs=100,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7998 - loss: 0.5130 - val_accuracy: 0.7969 - val_loss: 0.4615
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7999 - loss: 0.4442 - val_accuracy: 0.7969 - val_loss: 0.4424
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7897 - loss: 0.4330 - val_accuracy: 0.7969 - val_loss: 0.4342
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7966 - loss: 0.4315 - val_accuracy: 0.7969 - val_loss: 0.4283
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7990 - loss: 0.4175 - val_accuracy: 0.8087 - val_loss: 0.4239
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8038 - loss: 0.4206 - val_accuracy: 0.8131 - val_loss: 0.4184
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8195 - loss: 0.4012 - val_accuracy: 0.8213 - val_loss: 0.4130
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8211 - loss: 0.4124 - val_accuracy: 0.8219 - val_loss: 0.4090
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8149 - loss: 0.4106 - val_accuracy: 0.8269 - val_loss: 0.4050
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8301 - loss: 0.3949 - val_accuracy: 0.8244 - val_loss: 0.4014
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8255 - loss: 0.3859 - val_accuracy: 0.8350 - val_loss: 0.3982
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8364 - loss: 0.3812 - val_accuracy: 0.8319 - val_loss: 0.3958
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8402 - loss: 0.3797 - val_accuracy: 0.8375 - val_loss: 0.3937
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8467 - loss: 0.3781 - val_accuracy: 0.8350 - val_loss: 0.3916
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8412 - loss: 0.3794 - val_accuracy: 0.8381 - val_loss: 0.3894
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8409 - loss: 0.3783 - val_accuracy: 0.8406 - val_loss: 0.3875
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8375 - loss: 0.3802 - val_accuracy: 0.8406 - val_loss: 0.3862
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8372 - loss: 0.3855 - val_accuracy: 0.8400 - val_loss: 0.3854
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8425 - loss: 0.3752 - val_accuracy: 0.8444 - val_loss: 0.3852
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8499 - loss: 0.3607 - val_accuracy: 0.8469 - val_loss: 0.3817
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8573 - loss: 0.3502 - val_accuracy: 0.8512 - val_loss: 0.3802
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8505 - loss: 0.3655 - val_accuracy: 0.8487 - val_loss: 0.3798
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8491 - loss: 0.3610 - val_accuracy: 0.8469 - val_loss: 0.3790
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8478 - loss: 0.3677 - val_accuracy: 0.8494 - val_loss: 0.3793
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8486 - loss: 0.3621 - val_accuracy: 0.8519 - val_loss: 0.3775
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8436 - loss: 0.3687 - val_accuracy: 0.8487 - val_loss: 0.3773
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8614 - loss: 0.3439 - val_accuracy: 0.8519 - val_loss: 0.3764
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8542 - loss: 0.3549 - val_accuracy: 0.8487 - val_loss: 0.3764
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8564 - loss: 0
#   0.8487499952316284,
#   0.846875011920929,
#   0.8493750095367432,
#   0.8518750071525574,
#   0.8487499952316284,
#   0.8518750071525574,
#   0.8487499952316284,
#   0.8512499928474426,
#   0.8493750095367432,
#   0.8512499928474426,
#   0.8506249785423279,
#   0.8500000238418579,
#   0.8518750071525574,
#   0.8493750095367432],
#  'val_loss': [0.4614707827568054,
#   0.4424239993095398,
#   0.4342167377471924,
#   0.42833229899406433,
#   0.4238670766353607,
#   0.4183691143989563,
#   0.4130151867866516,
#   0.40901678800582886,
#   0.4050326645374298,
#   0.4013752341270447,
#   0.39824923872947693,
#   0.39580971002578735,
#   0.3937493562698364,
#   0.3916054964065552,
#   0.38936835527420044,
#   0.38753047585487366,
#   0.3862316608428955,
#   0.3853610157966614,
#   0.3852001428604126,
#   0.3816567361354828,
#   0.3801575005054474,
#   0.3798117935657501,
#   0.37899884581565857,
#   0.379321813583374,
#   0.3775019943714142,
#   0.3773496747016907,
#   0.3764140009880066,
#   0.3764427900314331,
#   0.3754148781299591,
#   0.37551993131637573,
#   0.3740851879119873,
#   0.37354564666748047,
#   0.37314876914024353,
#   0.37333694100379944,
#   0.37305155396461487]}

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (32, 8)                │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (32, 8)                │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (32, 1)                │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 557 (2.18 KB)
#  Trainable params: 185 (740.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 372 (1.46 KB)

# %%
model.evaluate(X_test,y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8512 - loss: 0.3577
# [0.36799365282058716, 0.8519999980926514]

# %%
# Raw input
custom = [[600,'France','Male',40,3,60000,2,1,1,50000]]

df_custom = pd.DataFrame(custom, columns=[
    'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
    'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary'
])

df_custom['Gender'] = le.transform(df_custom['Gender'])

df_custom = ct.transform(df_custom)

df_custom = sc.transform(df_custom)

# %%
ans = model.predict(df_custom)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
ans
# Out:
# array([[0.0976881]], dtype=float32)

# %%
print("YES" if ans >= 0.5 else "NO")
# Out:
# NO

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
y_true = y_test.values
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

print("Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[1508   87]
#  [ 209  196]]
# Accuracy: 0.852
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1595
#            1       0.69      0.48      0.57       405
#
#     accuracy                           0.85      2000
#    macro avg       0.79      0.71      0.74      2000
# weighted avg       0.84      0.85      0.84      2000

# %% [markdown]
# Precision, recall, and F1-score are metrics used to evaluate classification models, especially when the data is imbalanced.
#
# Precision shows how often the model’s positive predictions are actually correct, while recall shows how many of the real positive cases the model is able to find. F1-score combines both precision and recall into a single value, giving a balanced measure of performance.
#
# These metrics are more reliable than accuracy alone because accuracy can look high even when a model performs poorly on important classes. Precision, recall, and F1-score give deeper insight into the types of mistakes the model makes.
#
# Other useful metrics include specificity, ROC-AUC, log loss, and MCC, which help evaluate different aspects of model performance.
